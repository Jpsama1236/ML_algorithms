# %% [markdown]
# <a href="https://colab.research.google.com/github/Jpsama1236/ML_algorithms/blob/main/Feature_importance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_classification
from sklearn.tree import DecisionTreeClassifier

# %%
X,y=make_classification(n_samples=100,n_features=2,n_informative=2,n_redundant=0,n_classes=2,random_state=43)

# %%
X.shape
# Out:
# (100, 2)

# %%
y.shape
# Out:
# (100,)

# %%
clf = DecisionTreeClassifier()

# %%
clf.fit(X,y)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import plot_tree

# %%
plot_tree(clf)
# Out:
# [Text(0.4, 0.9, 'x[1] <= -0.052\ngini = 0.5\nsamples = 100\nvalue = [50, 50]'),
#  Text(0.13333333333333333, 0.7, 'x[0] <= 1.133\ngini = 0.081\nsamples = 47\nvalue = [45, 2]'),
#  Text(0.06666666666666667, 0.5, 'gini = 0.0\nsamples = 36\nvalue = [36, 0]'),
#  Text(0.2, 0.5, 'x[1] <= -1.081\ngini = 0.298\nsamples = 11\nvalue = [9, 2]'),
#  Text(0.13333333333333333, 0.3, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]'),
#  Text(0.26666666666666666, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(0.6666666666666666, 0.7, 'x[1] <= 0.573\ngini = 0.171\nsamples = 53\nvalue = [5, 48]'),
#  Text(0.4666666666666667, 0.5, 'x[0] <= -0.842\ngini = 0.48\nsamples = 10\nvalue = [4, 6]'),
#  Text(0.4, 0.3, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(0.5333333333333333, 0.3, 'x[1] <= -0.003\ngini = 0.32\nsamples = 5\nvalue = [4, 1]'),
#  Text(0.4666666666666667, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(0.6, 0.1, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
# ...

# %%
clf.feature_importances_
# Out:
# array([0.11421097, 0.88578903])

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier(n_estimators=2)
rf.fit(X,y)
# Out:
# RandomForestClassifier(n_estimators=2)

# %%
rf.feature_importances_
# Out:
# array([0.17808733, 0.82191267])

# %%
print(rf.estimators_[0].feature_importances_)
print(rf.estimators_[1].feature_importances_)
# Out:
# [0.20040853 0.79959147]
# [0.15576613 0.84423387]

# %%
(0.2+0.15)/2
# Out:
# 0.175

# %% [markdown]
# randomForest just averages the feature importances given by each estimator decision tree
