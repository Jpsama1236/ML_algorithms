# %% [markdown]
# <a href="https://colab.research.google.com/github/Jpsama1236/ML_algorithms/blob/main/MLR.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sklearn.datasets import load_diabetes

# %%
x,y=load_diabetes(return_X_y=True)

# %%
print(x)
# Out:
# [[ 0.03807591  0.05068012  0.06169621 ... -0.00259226  0.01990749
#   -0.01764613]
#  [-0.00188202 -0.04464164 -0.05147406 ... -0.03949338 -0.06833155
#   -0.09220405]
#  [ 0.08529891  0.05068012  0.04445121 ... -0.00259226  0.00286131
#   -0.02593034]
#  ...
#  [ 0.04170844  0.05068012 -0.01590626 ... -0.01107952 -0.04688253
#    0.01549073]
#  [-0.04547248 -0.04464164  0.03906215 ...  0.02655962  0.04452873
#   -0.02593034]
#  [-0.04547248 -0.04464164 -0.0730303  ... -0.03949338 -0.00422151
#    0.00306441]]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=43)

# %%
X_train.shape
# Out:
# (353, 10)

# %%
X_train
# Out:
# array([[ 0.00538306,  0.05068012,  0.03043966, ..., -0.03949338,
#          0.0086406 ,  0.01549073],
#        [-0.09996055, -0.04464164, -0.06764124, ..., -0.03949338,
#         -0.04987245, -0.00936191],
#        [ 0.06350368,  0.05068012, -0.00405033, ..., -0.00259226,
#          0.08449153, -0.01764613],
#        ...,
#        [ 0.00175052, -0.04464164, -0.06548562, ..., -0.03949338,
#         -0.00330084,  0.00720652],
#        [-0.02367725, -0.04464164,  0.03043966, ...,  0.07120998,
#          0.03304307,  0.00306441],
#        [ 0.03081083, -0.04464164,  0.00564998, ...,  0.1081111 ,
#          0.06605067,  0.01963284]])

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
ypred=lr.predict(X_test)

# %%
print(lr.intercept_)
# Out:
# 152.0532454782767

# %%
print(lr.coef_)
# Out:
# [ -60.39984809 -226.08359044  529.38495719  259.96199412 -859.09300933
#   504.68697339  157.41085788  226.29313436  840.7840406    34.71226556]

# %%
from sklearn.metrics import r2_score

# %%
print(r2_score(y_test,ypred))
# Out:
# 0.5419836643066976

# %% [markdown]
# Making our own Linear Regression Class

# %%
class Myclass:
  def __init__(self):
    self.intercept_=None
    self.coef_ = None

  def fit(self,X_train,y_train):
    X_train=np.insert(X_train,0,1,axis=1)
    betas=np.linalg.inv(np.dot(X_train.T,X_train)).dot(X_train.T).dot(y_train)
    self.intercept_=betas[0]
    self.coef_=betas[1:]

  def predict(self,X_test):
    ypred=np.dot(X_test,self.coef_)+self.intercept_
    return ypred

# %%
lr=Myclass()

# %%
lr.fit(X_train,y_train)

# %%
ypred=lr.predict(X_test)

# %%
print(r2_score(y_test,ypred))
# Out:
# 0.5419836643066978

# %%
print(lr.coef_)
# Out:
# [ -60.39984809 -226.08359044  529.38495719  259.96199412 -859.09300933
#   504.68697339  157.41085788  226.29313436  840.7840406    34.71226556]
